# %% [markdown]
# ## 載入函式庫 & 掛載雲端硬碟

# %%
import os
from google.colab import drive
import copy
import numpy
import numpy as np
import pandas as pd
import librosa

import tensorflow as tf
from tensorflow.keras.layers import Activation, BatchNormalization, Dense, LayerNormalization
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import datasets, layers, models

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, recall_score
from sklearn.preprocessing import MinMaxScaler

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn import svm
from sklearn.metrics import classification_report, accuracy_score

import scipy.io.wavfile
from scipy.fftpack import dct

drive.mount('/content/drive')

os.chdir('/content/drive/MyDrive/Colab Notebooks/Voice-Diease/')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 載入訓練資料

# %%
# 讀取訓練資料集表單
source_df = pd.read_csv('./data/training_datalist.csv')

print("source_df.shape :", source_df.shape)

class_weight = {0: 1.,
          1: 2.436,
          2: 3.19,
          3: 12.182,
          4: 16.75,}
# Out:
# source_df.shape : (1000, 28)

# %% [markdown]
# ## 切分訓練與驗證資料

# %%
training_df, validate_df = train_test_split(source_df, test_size=0.15, random_state=333)

print("training_df shape :", training_df.shape, ", test_df shape :", validate_df.shape)
# Out:
# training_df shape : (850, 28) , test_df shape : (150, 28)

# %% [markdown]
# ## 聲學音檔轉換MFCC特徵

# %%
def MFCCs(filename):
  # setup
  sample_rate, raw_signal = scipy.io.wavfile.read(filename) # File assumed to be in the same directory
  signal = np.zeros(int(3.5*44100)) #fix audio to 3.5 seconds
  if(len(raw_signal) <= len(signal)):
    signal[:len(raw_signal)] = raw_signal
  else:
    signal = raw_signal[:len(signal)]

  emphasized_signal = signal
  # #pre-emphasis
  # pre_emphasis = 0.97
  # emphasized_signal = numpy.append(signal[0], signal[1:] - pre_emphasis * signal[:-1])

  #framing
  frame_size = 0.025
  frame_stride = 0.01

  frame_length, frame_step = frame_size * sample_rate, frame_stride * sample_rate  # Convert from seconds to samples
  signal_length = len(emphasized_signal)
  frame_length = int(round(frame_length))
  frame_step = int(round(frame_step))
  num_frames = int(numpy.ceil(float(numpy.abs(signal_length - frame_length)) / frame_step))  # Make sure that we have at least 1 frame

  pad_signal_length = num_frames * frame_step + frame_length
  z = numpy.zeros((pad_signal_length - signal_length))
  pad_signal = numpy.append(emphasized_signal, z) # Pad Signal to make sure that all frames have equal number of samples without truncating any samples from the original signal

  indices = numpy.tile(numpy.arange(0, frame_length), (num_frames, 1)) + numpy.tile(numpy.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
  frames = pad_signal[indices.astype(numpy.int32, copy=False)]

  #window
  frames *= numpy.hamming(frame_length)
  # frames *= 0.54 - 0.46 * numpy.cos((2 * numpy.pi * n) / (frame_length - 1))  # Explicit Implementation **

  #Fourier-Transform and Power Spectrum
  NFFT = 512
  mag_frames = numpy.absolute(numpy.fft.rfft(frames, NFFT))  # Magnitude of the FFT
  pow_frames = ((1.0 / NFFT) * ((mag_frames) ** 2))  # Power Spectrum

  #Filter Banks
  nfilt =40
  low_freq_mel = 0
  high_freq_mel = (2595 * numpy.log10(1 + (sample_rate / 2) / 700))  # Convert Hz to Mel
  mel_points = numpy.linspace(low_freq_mel, high_freq_mel, nfilt + 2)  # Equally spaced in Mel scale
  hz_points = (700 * (10**(mel_points / 2595) - 1))  # Convert Mel to Hz
  bin = numpy.floor((NFFT + 1) * hz_points / sample_rate)

  fbank = numpy.zeros((nfilt, int(numpy.floor(NFFT / 2 + 1))))
  for m in range(1, nfilt + 1):
      f_m_minus = int(bin[m - 1])   # left
      f_m = int(bin[m])             # center
      f_m_plus = int(bin[m + 1])    # right

      for k in range(f_m_minus, f_m):
          fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
      for k in range(f_m, f_m_plus):
          fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])
  filter_banks = numpy.dot(pow_frames, fbank.T)
  filter_banks = numpy.where(filter_banks == 0, numpy.finfo(float).eps, filter_banks)  # Numerical Stability
  filter_banks = 20 * numpy.log10(filter_banks)  # dB
  filter_banks -= (numpy.mean(filter_banks, axis=0) + 1e-8)

  return filter_banks

# %%
def audioData_preprocessing(input_df, file_path):
  id_list = input_df.ID.tolist()
  data_size = input_df.shape[0]
  audio_feature = []
  for i in range(0, data_size):
    audio_feature.append(MFCCs(file_path + "{}.wav".format(id_list[i])))

  return np.array(audio_feature)

# %%
y_train = pd.get_dummies(training_df, columns=['Disease category']).to_numpy()[:,-5:].astype('float32')
x_train = audioData_preprocessing(training_df, file_path = "./data/training_data/")
print(x_train.shape, y_train.shape)

y_val = pd.get_dummies(validate_df, columns=['Disease category']).to_numpy()[:,-5:].astype('float32')
x_val = audioData_preprocessing(validate_df, file_path = "./data/training_data/")
print(x_val.shape, y_val.shape)
# Out:
# (850, 348, 40) (850, 5)
# (150, 348, 40) (150, 5)

# %% [markdown]
# ## 模型

# %%
def create_AudioModel(input_shape):
  model = Sequential()
  model.add(layers.Input(shape=(348, 40, 1)))
  #model.add(layers.Input(shape=(351, 39, 1)))
  model.add(layers.Conv2D(32, (3, 3), padding='same'))
  model.add(LayerNormalization())
  model.add(Activation('relu'))
  model.add(layers.MaxPooling2D())
  #model.add(layers.Dropout(0.2))

  model.add(layers.Conv2D(64, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(layers.MaxPooling2D())
  #model.add(layers.Dropout(0.2))

  model.add(layers.Conv2D(96, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(layers.MaxPooling2D())
  #model.add(layers.Dropout(0.2))

  model.add(layers.Conv2D(192, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(layers.MaxPooling2D())
  #model.add(layers.Dropout(0.2))

  model.add(layers.Flatten())
  model.add(layers.Dense(64))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  #model.add(layers.Dropout(0.2))
  model.add(layers.Dense(5, activation='softmax'))
  model.summary()

  model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )
  return model

# %% [markdown]
# ## 訓練

# %%
audio_model = create_AudioModel(input_shape = x_train.shape[1])
print(x_train.shape)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 348, 40, 32)       320
#
#  layer_normalization (LayerN  (None, 348, 40, 32)      64
#  ormalization)
#
#  activation (Activation)     (None, 348, 40, 32)       0
#
#  max_pooling2d (MaxPooling2D  (None, 174, 20, 32)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 174, 20, 64)       18496
#
#  batch_normalization (BatchN  (None, 174, 20, 64)      256
#  ormalization)
#
#  activation_1 (Activation)   (None, 174, 20, 64)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 87, 10, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 87, 10, 96)        55392
#
#  batch_normalization_1 (Batc  (None, 87, 10, 96)       384
#  hNormalization)
#
#  activation_2 (Activation)   (None, 87, 10, 96)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 43, 5, 96)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 43, 5, 192)        166080
#
#  batch_normalization_2 (Batc  (None, 43, 5, 192)       768
#  hNormalization)
#
#  activation_3 (Activation)   (None, 43, 5, 192)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 21, 2, 192)       0
#  2D)
#
#  flatten (Flatten)           (None, 8064)              0
#
#  dense (Dense)               (None, 64)                516160
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_4 (Activation)   (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 758,501
# Trainable params: 757,669
# Non-trainable params: 832
# _________________________________________________________________
# (850, 348, 40)

# %%
train_history = audio_model.fit(x_train, y_train, batch_size=256, epochs=3000, class_weight = class_weight,
                                callbacks=[EarlyStopping(monitor='loss', patience=2000, mode='auto'),
                                           ModelCheckpoint("audio_model.h5", save_best_only=True, monitor='val_accuracy')
                                          ], 
                                validation_data=(x_val, y_val)
                                )

score = audio_model.evaluate(x_val, y_val, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# Epoch 502/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.6541 - val_accuracy: 0.5333
# Epoch 503/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.6706 - val_accuracy: 0.5200
# Epoch 504/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.6794 - val_accuracy: 0.5200
# Epoch 505/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 1.6739 - val_accuracy: 0.5200
# Epoch 506/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.6767 - val_accuracy: 0.5133
# Epoch 507/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 1.7305 - val_accuracy: 0.4800
# Epoch 508/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.6600 - val_accuracy: 0.5467
# Epoch 509/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.6652 - val_accuracy: 0.5267
# Epoch 510/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.6934 - val_accuracy: 0.5267
# Epoch 511/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 1.6993 - val_accuracy: 0.5267
# Epoch 512/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.6780 - val_accuracy: 0.5467
# Epoch 513/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.6767 - val_accuracy: 0.5267
# Epoch 514/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.6794 - val_accuracy: 0.5267
# Epoch 515/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 1.6631 - val_accuracy: 0.5533
# Epoch 516/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.6666 - val_accuracy: 0.5400
# Epoch 517/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.6831 - val_accuracy: 0.5333
# Epoch 518/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 1.6762 - val_accuracy: 0.5333
# Epoch 519/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.6581 - val_accuracy: 0.5400
# Epoch 520/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 1.6680 - val_accuracy: 0.5467
# Epoch 521/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 1.7063 - val_accuracy: 0.5533
# Epoch 522/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.7093 - val_accuracy: 0.5400
# Epoch 523/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.6872 - val_accuracy: 0.5067
# Epoch 524/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 1.7277 - val_accuracy: 0.5067
# Epoch 525/3000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 1.6805 - val_accuracy: 0.5400
# Epoch 526/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.6564 - val_accuracy: 0.5267
# Epoch 527/3000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.6576 - val_accuracy: 0.5333
# Epoch 528/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.6651 - val_accuracy: 0.5400
# Epoch 529/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.6637 - val_accuracy: 0.5333
# Epoch 530/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.6645 - val_accuracy: 0.5333
# Epoch 531/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.6667 - val_accuracy: 0.5400
# Epoch 532/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.6677 - val_accuracy: 0.5533
# Epoch 533/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.6634 - val_accuracy: 0.5400
# Epoch 534/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.6542 - val_accuracy: 0.5467
# Epoch 535/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 1.6524 - val_accuracy: 0.5400
# Epoch 536/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 1.6542 - val_accuracy: 0.5533
# Epoch 537/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.6493 - val_accuracy: 0.5200
# Epoch 538/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.6665 - val_accuracy: 0.5267
# Epoch 539/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.6717 - val_accuracy: 0.5333
# Epoch 540/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.6645 - val_accuracy: 0.5400
# Epoch 541/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.6672 - val_accuracy: 0.5267
# Epoch 542/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.6832 - val_accuracy: 0.5267
# Epoch 543/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.6942 - val_accuracy: 0.5333
# Epoch 544/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.6490 - val_accuracy: 0.5333
# Epoch 545/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.6622 - val_accuracy: 0.5333
# Epoch 546/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.6918 - val_accuracy: 0.5133
# Epoch 547/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.6910 - val_accuracy: 0.5267
# Epoch 548/3000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.6770 - val_accuracy: 0.5333
# Epoch 549/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.6742 - val_accuracy: 0.5400
# Epoch 550/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.6805 - val_accuracy: 0.5333
# Epoch 551/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.6834 - val_accuracy: 0.5267
# Epoch 552/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.6804 - val_accuracy: 0.5200
# Epoch 553/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.6852 - val_accuracy: 0.5200
# Epoch 554/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.6889 - val_accuracy: 0.5400
# Epoch 555/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.6902 - val_accuracy: 0.5333
# Epoch 556/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.6909 - val_accuracy: 0.5267
# Epoch 557/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.7061 - val_accuracy: 0.5400
# Epoch 558/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 1.6811 - val_accuracy: 0.5333
# Epoch 559/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.6988 - val_accuracy: 0.5400
# Epoch 560/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.7233 - val_accuracy: 0.5333
# Epoch 561/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.7294 - val_accuracy: 0.5333
# Epoch 562/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.7096 - val_accuracy: 0.5333
# Epoch 563/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.7118 - val_accuracy: 0.5267
# Epoch 564/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.7218 - val_accuracy: 0.5200
# Epoch 565/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.7272 - val_accuracy: 0.5067
# Epoch 566/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.6898 - val_accuracy: 0.5400
# Epoch 567/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.6880 - val_accuracy: 0.5400
# Epoch 568/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.7188 - val_accuracy: 0.5400
# Epoch 569/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.6856 - val_accuracy: 0.5333
# Epoch 570/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.6841 - val_accuracy: 0.5600
# Epoch 571/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.6913 - val_accuracy: 0.5133
# Epoch 572/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.6852 - val_accuracy: 0.5267
# Epoch 573/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.6843 - val_accuracy: 0.5133
# Epoch 574/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.6891 - val_accuracy: 0.5200
# Epoch 575/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.7115 - val_accuracy: 0.5133
# Epoch 576/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.7114 - val_accuracy: 0.5400
# Epoch 577/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.7116 - val_accuracy: 0.5400
# Epoch 578/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.7175 - val_accuracy: 0.5467
# Epoch 579/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.7239 - val_accuracy: 0.5333
# Epoch 580/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.7126 - val_accuracy: 0.5200
# Epoch 581/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.7192 - val_accuracy: 0.5200
# Epoch 582/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.7145 - val_accuracy: 0.5267
# Epoch 583/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 1.6905 - val_accuracy: 0.5133
# Epoch 584/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.7074 - val_accuracy: 0.5200
# Epoch 585/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.7450 - val_accuracy: 0.5267
# Epoch 586/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.7254 - val_accuracy: 0.5333
# Epoch 587/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.7194 - val_accuracy: 0.5267
# Epoch 588/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.7484 - val_accuracy: 0.5200
# Epoch 589/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 1.7248 - val_accuracy: 0.5267
# Epoch 590/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.7019 - val_accuracy: 0.5333
# Epoch 591/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.7127 - val_accuracy: 0.5200
# Epoch 592/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.7283 - val_accuracy: 0.5133
# Epoch 593/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.7204 - val_accuracy: 0.5200
# Epoch 594/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.7109 - val_accuracy: 0.5267
# Epoch 595/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.7168 - val_accuracy: 0.5200
# Epoch 596/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.7122 - val_accuracy: 0.5200
# Epoch 597/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.6996 - val_accuracy: 0.5333
# Epoch 598/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.7180 - val_accuracy: 0.5333
# Epoch 599/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.7234 - val_accuracy: 0.5267
# Epoch 600/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.7133 - val_accuracy: 0.5267
# Epoch 601/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.7147 - val_accuracy: 0.5267
# Epoch 602/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.7137 - val_accuracy: 0.5333
# Epoch 603/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.7045 - val_accuracy: 0.5400
# Epoch 604/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.7211 - val_accuracy: 0.5267
# Epoch 605/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.7247 - val_accuracy: 0.5200
# Epoch 606/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.7064 - val_accuracy: 0.5200
# Epoch 607/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.7151 - val_accuracy: 0.5200
# Epoch 608/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.7364 - val_accuracy: 0.5267
# Epoch 609/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.7408 - val_accuracy: 0.5400
# Epoch 610/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.7180 - val_accuracy: 0.5267
# Epoch 611/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.7171 - val_accuracy: 0.5333
# Epoch 612/3000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.7179 - val_accuracy: 0.5267
# Epoch 613/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.7397 - val_accuracy: 0.5400
# Epoch 614/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.7264 - val_accuracy: 0.5133
# Epoch 615/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.7230 - val_accuracy: 0.5333
# Epoch 616/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.7213 - val_accuracy: 0.5200
# Epoch 617/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.7169 - val_accuracy: 0.5133
# Epoch 618/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.7233 - val_accuracy: 0.5267
# Epoch 619/3000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.7289 - val_accuracy: 0.5200
# Epoch 620/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.7183 - val_accuracy: 0.5400
# Epoch 621/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.7106 - val_accuracy: 0.5467
# Epoch 622/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.7098 - val_accuracy: 0.5333
# Epoch 623/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.7190 - val_accuracy: 0.5333
# Epoch 624/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.7227 - val_accuracy: 0.5133
# Epoch 625/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.7397 - val_accuracy: 0.5133
# Epoch 626/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.7544 - val_accuracy: 0.5133
# Epoch 627/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.7490 - val_accuracy: 0.5133
# Epoch 628/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.7431 - val_accuracy: 0.5067
# Epoch 629/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.7446 - val_accuracy: 0.5000
# Epoch 630/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.7371 - val_accuracy: 0.5067
# Epoch 631/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.7385 - val_accuracy: 0.5133
# Epoch 632/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.7455 - val_accuracy: 0.5133
# Epoch 633/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.7626 - val_accuracy: 0.5133
# Epoch 634/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.7663 - val_accuracy: 0.5133
# Epoch 635/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.7381 - val_accuracy: 0.5133
# Epoch 636/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.7206 - val_accuracy: 0.5133
# Epoch 637/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.7344 - val_accuracy: 0.5267
# Epoch 638/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.7433 - val_accuracy: 0.5133
# Epoch 639/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.7307 - val_accuracy: 0.5333
# Epoch 640/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.7291 - val_accuracy: 0.5333
# Epoch 641/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.7172 - val_accuracy: 0.5067
# Epoch 642/3000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.7132 - val_accuracy: 0.5200
# Epoch 643/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.7343 - val_accuracy: 0.5067
# Epoch 644/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.7619 - val_accuracy: 0.5133
# Epoch 645/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.7738 - val_accuracy: 0.5133
# Epoch 646/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.7554 - val_accuracy: 0.5200
# Epoch 647/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.7482 - val_accuracy: 0.5067
# Epoch 648/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.7516 - val_accuracy: 0.5067
# Epoch 649/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.7629 - val_accuracy: 0.5133
# Epoch 650/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.7413 - val_accuracy: 0.5200
# Epoch 651/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.7441 - val_accuracy: 0.5067
# Epoch 652/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.7648 - val_accuracy: 0.5267
# Epoch 653/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.7512 - val_accuracy: 0.5200
# Epoch 654/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.7315 - val_accuracy: 0.5067
# Epoch 655/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.8184 - val_accuracy: 0.5133
# Epoch 656/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.7778 - val_accuracy: 0.5067
# Epoch 657/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.7199 - val_accuracy: 0.5200
# Epoch 658/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.7350 - val_accuracy: 0.5267
# Epoch 659/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.7530 - val_accuracy: 0.5267
# Epoch 660/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.7254 - val_accuracy: 0.5533
# Epoch 661/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.7248 - val_accuracy: 0.5400
# Epoch 662/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.7350 - val_accuracy: 0.5267
# Epoch 663/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.7380 - val_accuracy: 0.5333
# Epoch 664/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.7542 - val_accuracy: 0.5400
# Epoch 665/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.7506 - val_accuracy: 0.5267
# Epoch 666/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.7455 - val_accuracy: 0.5267
# Epoch 667/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.7549 - val_accuracy: 0.5200
# Epoch 668/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.7594 - val_accuracy: 0.5267
# Epoch 669/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.7535 - val_accuracy: 0.5133
# Epoch 670/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.7552 - val_accuracy: 0.5200
# Epoch 671/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.7546 - val_accuracy: 0.5267
# Epoch 672/3000
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.7550 - val_accuracy: 0.5133
# Epoch 673/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.7497 - val_accuracy: 0.5333
# Epoch 674/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.7487 - val_accuracy: 0.5133
# Epoch 675/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.7681 - val_accuracy: 0.5133
# Epoch 676/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.7650 - val_accuracy: 0.5067
# Epoch 677/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.7467 - val_accuracy: 0.5067
# Epoch 678/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.7606 - val_accuracy: 0.5200
# Epoch 679/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.7705 - val_accuracy: 0.5200
# Epoch 680/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.7516 - val_accuracy: 0.5200
# Epoch 681/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.7559 - val_accuracy: 0.5267
# Epoch 682/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.7577 - val_accuracy: 0.5067
# Epoch 683/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7504 - val_accuracy: 0.5133
# Epoch 684/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7461 - val_accuracy: 0.5200
# Epoch 685/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.7508 - val_accuracy: 0.5200
# Epoch 686/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7439 - val_accuracy: 0.5200
# Epoch 687/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7388 - val_accuracy: 0.5267
# Epoch 688/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7508 - val_accuracy: 0.5133
# Epoch 689/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7640 - val_accuracy: 0.5200
# Epoch 690/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.7627 - val_accuracy: 0.5267
# Epoch 691/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.7644 - val_accuracy: 0.5200
# Epoch 692/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7683 - val_accuracy: 0.5133
# Epoch 693/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7670 - val_accuracy: 0.5200
# Epoch 694/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.7582 - val_accuracy: 0.5267
# Epoch 695/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7623 - val_accuracy: 0.5267
# Epoch 696/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7483 - val_accuracy: 0.5267
# Epoch 697/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.7393 - val_accuracy: 0.5267
# Epoch 698/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7387 - val_accuracy: 0.5267
# Epoch 699/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.7510 - val_accuracy: 0.5133
# Epoch 700/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7548 - val_accuracy: 0.5200
# Epoch 701/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.7529 - val_accuracy: 0.5133
# Epoch 702/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.7495 - val_accuracy: 0.5333
# Epoch 703/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.7513 - val_accuracy: 0.5333
# Epoch 704/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.7571 - val_accuracy: 0.5267
# Epoch 705/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.7662 - val_accuracy: 0.5267
# Epoch 706/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7480 - val_accuracy: 0.5067
# Epoch 707/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7453 - val_accuracy: 0.5200
# Epoch 708/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.7652 - val_accuracy: 0.5333
# Epoch 709/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.7595 - val_accuracy: 0.5467
# Epoch 710/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.7489 - val_accuracy: 0.5467
# Epoch 711/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.7465 - val_accuracy: 0.5600
# Epoch 712/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.7478 - val_accuracy: 0.5400
# Epoch 713/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.7561 - val_accuracy: 0.5467
# Epoch 714/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.7619 - val_accuracy: 0.5400
# Epoch 715/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7571 - val_accuracy: 0.5200
# Epoch 716/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.7557 - val_accuracy: 0.5267
# Epoch 717/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7695 - val_accuracy: 0.5200
# Epoch 718/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.7777 - val_accuracy: 0.5133
# Epoch 719/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7578 - val_accuracy: 0.5267
# Epoch 720/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.7590 - val_accuracy: 0.5333
# Epoch 721/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.7600 - val_accuracy: 0.5333
# Epoch 722/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.7657 - val_accuracy: 0.5267
# Epoch 723/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7522 - val_accuracy: 0.5267
# Epoch 724/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.7618 - val_accuracy: 0.5267
# Epoch 725/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.7705 - val_accuracy: 0.5200
# Epoch 726/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.7653 - val_accuracy: 0.5267
# Epoch 727/3000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.7561 - val_accuracy: 0.5400
# Epoch 728/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.7680 - val_accuracy: 0.5200
# Epoch 729/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.7639 - val_accuracy: 0.5333
# Epoch 730/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.7553 - val_accuracy: 0.5467
# Epoch 731/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.7503 - val_accuracy: 0.5333
# Epoch 732/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7603 - val_accuracy: 0.5267
# Epoch 733/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.7600 - val_accuracy: 0.5400
# Epoch 734/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.7534 - val_accuracy: 0.5267
# Epoch 735/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.7607 - val_accuracy: 0.5000
# Epoch 736/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.7947 - val_accuracy: 0.5133
# Epoch 737/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.7873 - val_accuracy: 0.5333
# Epoch 738/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7874 - val_accuracy: 0.5333
# Epoch 739/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.7833 - val_accuracy: 0.5200
# Epoch 740/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.7955 - val_accuracy: 0.5267
# Epoch 741/3000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7882 - val_accuracy: 0.5133
# Epoch 742/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7876 - val_accuracy: 0.5067
# Epoch 743/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.7998 - val_accuracy: 0.5200
# Epoch 744/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.7760 - val_accuracy: 0.5200
# Epoch 745/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7811 - val_accuracy: 0.5333
# Epoch 746/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.7919 - val_accuracy: 0.5333
# Epoch 747/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7783 - val_accuracy: 0.5133
# Epoch 748/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.7720 - val_accuracy: 0.5067
# Epoch 749/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.7902 - val_accuracy: 0.5200
# Epoch 750/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.8241 - val_accuracy: 0.5067
# Epoch 751/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.8219 - val_accuracy: 0.5067
# Epoch 752/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.8280 - val_accuracy: 0.5133
# Epoch 753/3000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.8189 - val_accuracy: 0.5133
# Epoch 754/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.8036 - val_accuracy: 0.5200
# Epoch 755/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.7806 - val_accuracy: 0.5333
# Epoch 756/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.7700 - val_accuracy: 0.5400
# Epoch 757/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7826 - val_accuracy: 0.5467
# Epoch 758/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.8145 - val_accuracy: 0.5267
# Epoch 759/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.8172 - val_accuracy: 0.5333
# Epoch 760/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.8064 - val_accuracy: 0.5200
# Epoch 761/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.8130 - val_accuracy: 0.5067
# Epoch 762/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.7930 - val_accuracy: 0.5200
# Epoch 763/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.7868 - val_accuracy: 0.5200
# Epoch 764/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.7930 - val_accuracy: 0.5400
# Epoch 765/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.7774 - val_accuracy: 0.5200
# Epoch 766/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7747 - val_accuracy: 0.5200
# Epoch 767/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.7965 - val_accuracy: 0.5067
# Epoch 768/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.7976 - val_accuracy: 0.5133
# Epoch 769/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.7899 - val_accuracy: 0.5200
# Epoch 770/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.7864 - val_accuracy: 0.5267
# Epoch 771/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.7992 - val_accuracy: 0.5267
# Epoch 772/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.8114 - val_accuracy: 0.5267
# Epoch 773/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.8028 - val_accuracy: 0.5200
# Epoch 774/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.7910 - val_accuracy: 0.5200
# Epoch 775/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.7985 - val_accuracy: 0.5133
# Epoch 776/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.8381 - val_accuracy: 0.5000
# Epoch 777/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.8262 - val_accuracy: 0.5133
# Epoch 778/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.8002 - val_accuracy: 0.5133
# Epoch 779/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.7895 - val_accuracy: 0.5200
# Epoch 780/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.7874 - val_accuracy: 0.5200
# Epoch 781/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.7812 - val_accuracy: 0.5133
# Epoch 782/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.7897 - val_accuracy: 0.5200
# Epoch 783/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.8069 - val_accuracy: 0.5267
# Epoch 784/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.8032 - val_accuracy: 0.5267
# Epoch 785/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.8048 - val_accuracy: 0.5200
# Epoch 786/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.7963 - val_accuracy: 0.5333
# Epoch 787/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.7828 - val_accuracy: 0.5400
# Epoch 788/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.8005 - val_accuracy: 0.5133
# Epoch 789/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.8319 - val_accuracy: 0.5200
# Epoch 790/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.8330 - val_accuracy: 0.5333
# Epoch 791/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.8158 - val_accuracy: 0.5067
# Epoch 792/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.8167 - val_accuracy: 0.5200
# Epoch 793/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.8474 - val_accuracy: 0.4933
# Epoch 794/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.8060 - val_accuracy: 0.5133
# Epoch 795/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.7844 - val_accuracy: 0.5267
# Epoch 796/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.8143 - val_accuracy: 0.5267
# Epoch 797/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.8284 - val_accuracy: 0.5133
# Epoch 798/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.8064 - val_accuracy: 0.5133
# Epoch 799/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.8129 - val_accuracy: 0.5200
# Epoch 800/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.8175 - val_accuracy: 0.5067
# Epoch 801/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.7979 - val_accuracy: 0.5000
# Epoch 802/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.8375 - val_accuracy: 0.5067
# Epoch 803/3000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.8598 - val_accuracy: 0.5067
# Epoch 804/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.8103 - val_accuracy: 0.5133
# Epoch 805/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.7987 - val_accuracy: 0.5267
# Epoch 806/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.8256 - val_accuracy: 0.5267
# Epoch 807/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.8402 - val_accuracy: 0.5067
# Epoch 808/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.8163 - val_accuracy: 0.5200
# Epoch 809/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.8027 - val_accuracy: 0.5200
# Epoch 810/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.8221 - val_accuracy: 0.5333
# Epoch 811/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.8153 - val_accuracy: 0.5133
# Epoch 812/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.8079 - val_accuracy: 0.5067
# Epoch 813/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.8298 - val_accuracy: 0.5200
# Epoch 814/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.8789 - val_accuracy: 0.5000
# Epoch 815/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.8164 - val_accuracy: 0.5200
# Epoch 816/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.7985 - val_accuracy: 0.5267
# Epoch 817/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.8095 - val_accuracy: 0.5267
# Epoch 818/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.7958 - val_accuracy: 0.5333
# Epoch 819/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.7826 - val_accuracy: 0.5333
# Epoch 820/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.8046 - val_accuracy: 0.5067
# Epoch 821/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.8416 - val_accuracy: 0.5067
# Epoch 822/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.8397 - val_accuracy: 0.5267
# Epoch 823/3000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.8267 - val_accuracy: 0.5133
# Epoch 824/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.8152 - val_accuracy: 0.5200
# Epoch 825/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.8083 - val_accuracy: 0.5200
# Epoch 826/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.8146 - val_accuracy: 0.5133
# Epoch 827/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.8132 - val_accuracy: 0.5133
# Epoch 828/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.8110 - val_accuracy: 0.5200
# Epoch 829/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.8350 - val_accuracy: 0.5200
# Epoch 830/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.8154 - val_accuracy: 0.5133
# Epoch 831/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.8073 - val_accuracy: 0.5200
# Epoch 832/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.8187 - val_accuracy: 0.5200
# Epoch 833/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.8107 - val_accuracy: 0.5000
# Epoch 834/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.8085 - val_accuracy: 0.5133
# Epoch 835/3000
# ...
# Epoch 2894/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 7.0633e-04 - accuracy: 1.0000 - val_loss: 2.0927 - val_accuracy: 0.4800
# Epoch 2895/3000
# 4/4 [==============================] - 0s 111ms/step - loss: 8.1530e-04 - accuracy: 1.0000 - val_loss: 2.0897 - val_accuracy: 0.5000
# Epoch 2896/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 8.0211e-04 - accuracy: 1.0000 - val_loss: 2.0510 - val_accuracy: 0.5000
# Epoch 2897/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 7.2260e-04 - accuracy: 1.0000 - val_loss: 2.0236 - val_accuracy: 0.5400
# Epoch 2898/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 8.7383e-04 - accuracy: 1.0000 - val_loss: 2.0165 - val_accuracy: 0.5467
# Epoch 2899/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 7.0403e-04 - accuracy: 1.0000 - val_loss: 2.0314 - val_accuracy: 0.5400
# Epoch 2900/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.5120e-04 - accuracy: 1.0000 - val_loss: 2.0629 - val_accuracy: 0.5267
# Epoch 2901/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 7.1923e-04 - accuracy: 1.0000 - val_loss: 2.0737 - val_accuracy: 0.5333
# Epoch 2902/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 7.1544e-04 - accuracy: 1.0000 - val_loss: 2.0593 - val_accuracy: 0.5200
# Epoch 2903/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.5027e-04 - accuracy: 1.0000 - val_loss: 2.0435 - val_accuracy: 0.5333
# Epoch 2904/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.9742e-04 - accuracy: 1.0000 - val_loss: 2.0372 - val_accuracy: 0.5400
# Epoch 2905/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 9.5668e-04 - accuracy: 1.0000 - val_loss: 2.0375 - val_accuracy: 0.5333
# Epoch 2906/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.1950e-04 - accuracy: 1.0000 - val_loss: 2.0461 - val_accuracy: 0.5000
# Epoch 2907/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.5451e-04 - accuracy: 1.0000 - val_loss: 2.0541 - val_accuracy: 0.5133
# Epoch 2908/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 7.0579e-04 - accuracy: 1.0000 - val_loss: 2.0539 - val_accuracy: 0.5000
# Epoch 2909/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.2695e-04 - accuracy: 1.0000 - val_loss: 2.0531 - val_accuracy: 0.5200
# Epoch 2910/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.9382e-04 - accuracy: 1.0000 - val_loss: 2.0567 - val_accuracy: 0.5333
# Epoch 2911/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.3360e-04 - accuracy: 1.0000 - val_loss: 2.0588 - val_accuracy: 0.5267
# Epoch 2912/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.5917e-04 - accuracy: 1.0000 - val_loss: 2.0591 - val_accuracy: 0.5200
# Epoch 2913/3000
# 4/4 [==============================] - 0s 111ms/step - loss: 6.5202e-04 - accuracy: 1.0000 - val_loss: 2.0612 - val_accuracy: 0.5200
# Epoch 2914/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.6888e-04 - accuracy: 1.0000 - val_loss: 2.0672 - val_accuracy: 0.5200
# Epoch 2915/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.2422e-04 - accuracy: 1.0000 - val_loss: 2.0748 - val_accuracy: 0.5067
# Epoch 2916/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.6549e-04 - accuracy: 1.0000 - val_loss: 2.0781 - val_accuracy: 0.5067
# Epoch 2917/3000
# 4/4 [==============================] - 0s 111ms/step - loss: 5.9611e-04 - accuracy: 1.0000 - val_loss: 2.0773 - val_accuracy: 0.5067
# Epoch 2918/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.1159e-04 - accuracy: 1.0000 - val_loss: 2.0716 - val_accuracy: 0.5133
# Epoch 2919/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.8438e-04 - accuracy: 1.0000 - val_loss: 2.0662 - val_accuracy: 0.5133
# Epoch 2920/3000
# 4/4 [==============================] - 0s 113ms/step - loss: 6.0616e-04 - accuracy: 1.0000 - val_loss: 2.0618 - val_accuracy: 0.5133
# Epoch 2921/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.1612e-04 - accuracy: 1.0000 - val_loss: 2.0635 - val_accuracy: 0.5067
# Epoch 2922/3000
# 4/4 [==============================] - 0s 114ms/step - loss: 6.2677e-04 - accuracy: 1.0000 - val_loss: 2.0682 - val_accuracy: 0.5133
# Epoch 2923/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.0518e-04 - accuracy: 1.0000 - val_loss: 2.0765 - val_accuracy: 0.5133
# Epoch 2924/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.8770e-04 - accuracy: 1.0000 - val_loss: 2.0827 - val_accuracy: 0.5067
# Epoch 2925/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.1778e-04 - accuracy: 1.0000 - val_loss: 2.0847 - val_accuracy: 0.5067
# Epoch 2926/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.8823e-04 - accuracy: 1.0000 - val_loss: 2.0838 - val_accuracy: 0.5067
# Epoch 2927/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.8377e-04 - accuracy: 1.0000 - val_loss: 2.0803 - val_accuracy: 0.5067
# Epoch 2928/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.5416e-04 - accuracy: 1.0000 - val_loss: 2.0790 - val_accuracy: 0.5000
# Epoch 2929/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.8439e-04 - accuracy: 1.0000 - val_loss: 2.0808 - val_accuracy: 0.5000
# Epoch 2930/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.4034e-04 - accuracy: 1.0000 - val_loss: 2.0842 - val_accuracy: 0.5000
# Epoch 2931/3000
# 4/4 [==============================] - 0s 112ms/step - loss: 6.4495e-04 - accuracy: 1.0000 - val_loss: 2.0856 - val_accuracy: 0.5067
# Epoch 2932/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.7599e-04 - accuracy: 1.0000 - val_loss: 2.0863 - val_accuracy: 0.5000
# Epoch 2933/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.3755e-04 - accuracy: 1.0000 - val_loss: 2.0889 - val_accuracy: 0.5067
# Epoch 2934/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.9375e-04 - accuracy: 1.0000 - val_loss: 2.0888 - val_accuracy: 0.5000
# Epoch 2935/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.5704e-04 - accuracy: 1.0000 - val_loss: 2.0925 - val_accuracy: 0.5000
# Epoch 2936/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.4016e-04 - accuracy: 1.0000 - val_loss: 2.0928 - val_accuracy: 0.5067
# Epoch 2937/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.6844e-04 - accuracy: 1.0000 - val_loss: 2.0914 - val_accuracy: 0.5000
# Epoch 2938/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.8452e-04 - accuracy: 1.0000 - val_loss: 2.0831 - val_accuracy: 0.5000
# Epoch 2939/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.0581e-04 - accuracy: 1.0000 - val_loss: 2.0821 - val_accuracy: 0.5000
# Epoch 2940/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.7962e-04 - accuracy: 1.0000 - val_loss: 2.0872 - val_accuracy: 0.5000
# Epoch 2941/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.7279e-04 - accuracy: 1.0000 - val_loss: 2.0922 - val_accuracy: 0.5000
# Epoch 2942/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.0502e-04 - accuracy: 1.0000 - val_loss: 2.0880 - val_accuracy: 0.4933
# Epoch 2943/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.9857e-04 - accuracy: 1.0000 - val_loss: 2.0790 - val_accuracy: 0.5000
# Epoch 2944/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.9455e-04 - accuracy: 1.0000 - val_loss: 2.0783 - val_accuracy: 0.5000
# Epoch 2945/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.5472e-04 - accuracy: 1.0000 - val_loss: 2.0786 - val_accuracy: 0.5067
# Epoch 2946/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.5471e-04 - accuracy: 1.0000 - val_loss: 2.0843 - val_accuracy: 0.4933
# Epoch 2947/3000
# 4/4 [==============================] - 0s 111ms/step - loss: 6.2400e-04 - accuracy: 1.0000 - val_loss: 2.0868 - val_accuracy: 0.4933
# Epoch 2948/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.5628e-04 - accuracy: 1.0000 - val_loss: 2.0924 - val_accuracy: 0.4933
# Epoch 2949/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.8451e-04 - accuracy: 1.0000 - val_loss: 2.0989 - val_accuracy: 0.4933
# Epoch 2950/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.0141e-04 - accuracy: 1.0000 - val_loss: 2.0975 - val_accuracy: 0.5000
# Epoch 2951/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.2593e-04 - accuracy: 1.0000 - val_loss: 2.1004 - val_accuracy: 0.4933
# Epoch 2952/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.5711e-04 - accuracy: 1.0000 - val_loss: 2.0972 - val_accuracy: 0.4933
# Epoch 2953/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.3805e-04 - accuracy: 1.0000 - val_loss: 2.0919 - val_accuracy: 0.4933
# Epoch 2954/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.0631e-04 - accuracy: 1.0000 - val_loss: 2.0866 - val_accuracy: 0.4933
# Epoch 2955/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.0548e-04 - accuracy: 1.0000 - val_loss: 2.0830 - val_accuracy: 0.5067
# Epoch 2956/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.1293e-04 - accuracy: 1.0000 - val_loss: 2.0825 - val_accuracy: 0.5067
# Epoch 2957/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.5021e-04 - accuracy: 1.0000 - val_loss: 2.0835 - val_accuracy: 0.5000
# Epoch 2958/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.0144e-04 - accuracy: 1.0000 - val_loss: 2.0772 - val_accuracy: 0.5000
# Epoch 2959/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.0263e-04 - accuracy: 1.0000 - val_loss: 2.0763 - val_accuracy: 0.5000
# Epoch 2960/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.5326e-04 - accuracy: 1.0000 - val_loss: 2.0788 - val_accuracy: 0.5000
# Epoch 2961/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.7008e-04 - accuracy: 1.0000 - val_loss: 2.0877 - val_accuracy: 0.4933
# Epoch 2962/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.2973e-04 - accuracy: 1.0000 - val_loss: 2.0957 - val_accuracy: 0.4933
# Epoch 2963/3000
# 4/4 [==============================] - 0s 112ms/step - loss: 5.5593e-04 - accuracy: 1.0000 - val_loss: 2.1008 - val_accuracy: 0.4867
# Epoch 2964/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.2113e-04 - accuracy: 1.0000 - val_loss: 2.1048 - val_accuracy: 0.4867
# Epoch 2965/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.6313e-04 - accuracy: 1.0000 - val_loss: 2.0989 - val_accuracy: 0.4933
# Epoch 2966/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.4072e-04 - accuracy: 1.0000 - val_loss: 2.0946 - val_accuracy: 0.5000
# Epoch 2967/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 4.9259e-04 - accuracy: 1.0000 - val_loss: 2.0915 - val_accuracy: 0.5000
# Epoch 2968/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.3922e-04 - accuracy: 1.0000 - val_loss: 2.0939 - val_accuracy: 0.5000
# Epoch 2969/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.2507e-04 - accuracy: 1.0000 - val_loss: 2.1011 - val_accuracy: 0.5000
# Epoch 2970/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.5753e-04 - accuracy: 1.0000 - val_loss: 2.1088 - val_accuracy: 0.5000
# Epoch 2971/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.4643e-04 - accuracy: 1.0000 - val_loss: 2.1097 - val_accuracy: 0.4933
# Epoch 2972/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.1040e-04 - accuracy: 1.0000 - val_loss: 2.1106 - val_accuracy: 0.4933
# Epoch 2973/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.5110e-04 - accuracy: 1.0000 - val_loss: 2.1046 - val_accuracy: 0.4867
# Epoch 2974/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.2014e-04 - accuracy: 1.0000 - val_loss: 2.0998 - val_accuracy: 0.4933
# Epoch 2975/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.3015e-04 - accuracy: 1.0000 - val_loss: 2.0939 - val_accuracy: 0.4933
# Epoch 2976/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 4.8444e-04 - accuracy: 1.0000 - val_loss: 2.0920 - val_accuracy: 0.5000
# Epoch 2977/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.7503e-04 - accuracy: 1.0000 - val_loss: 2.0953 - val_accuracy: 0.5000
# Epoch 2978/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.1179e-04 - accuracy: 1.0000 - val_loss: 2.0967 - val_accuracy: 0.4933
# Epoch 2979/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.6932e-04 - accuracy: 1.0000 - val_loss: 2.1021 - val_accuracy: 0.5000
# Epoch 2980/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.8197e-04 - accuracy: 1.0000 - val_loss: 2.0998 - val_accuracy: 0.5000
# Epoch 2981/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.1112e-04 - accuracy: 1.0000 - val_loss: 2.1028 - val_accuracy: 0.5000
# Epoch 2982/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 4.8471e-04 - accuracy: 1.0000 - val_loss: 2.1076 - val_accuracy: 0.5000
# Epoch 2983/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 4.7407e-04 - accuracy: 1.0000 - val_loss: 2.1119 - val_accuracy: 0.4933
# Epoch 2984/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.0598e-04 - accuracy: 1.0000 - val_loss: 2.1135 - val_accuracy: 0.4867
# Epoch 2985/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 4.7852e-04 - accuracy: 1.0000 - val_loss: 2.1121 - val_accuracy: 0.4867
# Epoch 2986/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.3224e-04 - accuracy: 1.0000 - val_loss: 2.1080 - val_accuracy: 0.4933
# Epoch 2987/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.7255e-04 - accuracy: 1.0000 - val_loss: 2.1011 - val_accuracy: 0.4933
# Epoch 2988/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.4426e-04 - accuracy: 1.0000 - val_loss: 2.1017 - val_accuracy: 0.4933
# Epoch 2989/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.0593e-04 - accuracy: 1.0000 - val_loss: 2.1022 - val_accuracy: 0.4933
# Epoch 2990/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.1058e-04 - accuracy: 1.0000 - val_loss: 2.1015 - val_accuracy: 0.4933
# Epoch 2991/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.4928e-04 - accuracy: 1.0000 - val_loss: 2.0882 - val_accuracy: 0.5000
# Epoch 2992/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 4.8465e-04 - accuracy: 1.0000 - val_loss: 2.0794 - val_accuracy: 0.5133
# Epoch 2993/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.1271e-04 - accuracy: 1.0000 - val_loss: 2.0818 - val_accuracy: 0.5133
# Epoch 2994/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.6328e-04 - accuracy: 1.0000 - val_loss: 2.0961 - val_accuracy: 0.5067
# Epoch 2995/3000
# 4/4 [==============================] - 0s 112ms/step - loss: 5.3112e-04 - accuracy: 1.0000 - val_loss: 2.1150 - val_accuracy: 0.5000
# Epoch 2996/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 4.7523e-04 - accuracy: 1.0000 - val_loss: 2.1273 - val_accuracy: 0.4933
# Epoch 2997/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.3914e-04 - accuracy: 1.0000 - val_loss: 2.1339 - val_accuracy: 0.5000
# Epoch 2998/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 4.7335e-04 - accuracy: 1.0000 - val_loss: 2.1320 - val_accuracy: 0.4933
# Epoch 2999/3000
# 4/4 [==============================] - 0s 109ms/step - loss: 4.9162e-04 - accuracy: 1.0000 - val_loss: 2.1240 - val_accuracy: 0.4933
# Epoch 3000/3000
# 4/4 [==============================] - 0s 110ms/step - loss: 4.9636e-04 - accuracy: 1.0000 - val_loss: 2.1138 - val_accuracy: 0.5000
# Test loss: 2.113783359527588
# Test accuracy: 0.5

# %% [markdown]
# ## 結果

# %%
audio_model = load_model("audio_model.h5")

# %%
y_pred = audio_model.predict(x_train).argmax(axis=1)
y_true = training_df['Disease category'] - 1

results_recall = recall_score(y_true, y_pred, average=None)
print("Training UAR(Unweighted Average Recall) :", results_recall.mean())
ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred)).plot(cmap='Blues')
# Out:
# 27/27 [==============================] - 0s 9ms/step
# Training UAR(Unweighted Average Recall) : 0.9947383784572722

# %%
y_pred = audio_model.predict(x_val).argmax(axis=1)
y_true = validate_df['Disease category'] - 1

results_recall = recall_score(y_true, y_pred, average=None)
print("Test UAR(Unweighted Average Recall) :", results_recall.mean())
ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred)).plot(cmap='Blues')
